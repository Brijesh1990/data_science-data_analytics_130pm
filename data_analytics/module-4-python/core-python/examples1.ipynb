# %%
# print additions of numbers 
a=int(input("Enter a Numbers :"))
b=int(input("Enter b Numbers :"))
c=a+b
print("Additions of numbers is :",c)
# Out:
# Enter a Numbers : 10
# Enter b Numbers : 20
# Additions of numbers is : 30
